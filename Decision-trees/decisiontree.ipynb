# %%
import numpy as np
import pandas as pd
from collections import Counter  
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text

# %%
data = pd.read_csv('/Users/nithin/Downloads/archive (1)/Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = data.drop(columns=["Id", "Species"]).values
y = data["Species"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=123)

# %%
class Node:
    def __init__(self, feature_idnx=None, threshold=None, info_gain=None, left=None, right=None, value=None):

        #decision node
        self.feature_idx = feature_idx
        self.threshold = threshold
        self.info_gain = info_gain
        self.left = left
        self.right = right

        #leaf node 
        self.value = value

# %%
class DecisionTree:
    def __init__(self, min_samples_split=2, max_depth=2):

        self.min_samples_split = min_sample_split
        self.max_depth = max_depth

    def build_tree(self, dataset, curr_depth=0):
        x, y = dataset[:, :-1], dataset[:, -1]
        n_samples, n_features = x.shape

        if n_samples >= self.min_samples_split and curr_dept <= self.max_depth:
            best_split = self.best_split(dataset, n_features)

            if best_split["info_gain"] > 0:
                left_node = self.build_tree(best_split["left_dataset"], curr_depth + 1)
                right_node = self.build_tree(best_split["right_dataset"], curr_depth + 1)

                return Node(best_split["feature_indx"], best_split["threshold"], best_split["info_gain"], left_node, right_node)

            left_value = Counter(y).most_common(1)[0][0]
            return Node(value=leaf_value)

    def best_split(self, dataset, n_features):
        best_split = {'feature_indx': None, 'threshold': None, 'info_gain': -1, 'left_dataset': None, 'right_dataset': None}

        for feature_indx in range(n_feature):
            feature_values = dataset[:, feature_indx]
            thresholds = np.unique(feature_values)

            for threshold in thresholds:
                left_dataset, right_dataset = self.split(dataset, feature_indx, threshold)

                if len(left_dataset) and len(right_dataset):
                    parent_y, left_y, right_y = dataset[:, -1], left_dataset[:, -1], right_dataset[:, -1]

                    info_gain = self.information_gain(parent_y, left_y, right_y)

                    if info_gain > best_split['info_gain']:
                        best_split['feature_indx'] = feature_indx
                        best_split['threshold'] = threshold
                        best_split['info_gain'] = info_gain
                        best_split['left_dataset'] = left_dataset
                        best_split['right_dataset'] = right_dataset

            return best_split

        def split(self, dataset, feature_indx, threshold):
            left_dataset = np.array([row for row in dataset if row[feature_indx] <= threshold])
            right_dataset =  np.array([row for row in dataset if row[feature_indx] > threshold])

            return left_dataset, right_dataset

        def information_gain(self, parent_y, left_y, right_y):
            left_weight = len(left_y) / len(parent_y)
            right_weight = len(right_y) / len(parent_y)

            information_gain = self.entropy(parent_y) - (left_weight * self.entropy(left_y) + right_weight * self.entropy(right_y))
            return information_gain

        def entropy(self, y):
            entropy = 0

            class_lables = np.unique(y)
            for class_label in class_lables:
                p = len(y[y==class_label]) / len(y)
                entropy += -p * np.log2(p)

            return entropy

        def fit(self, x, y):
            dataset = np.concatenate([x, y.reshape(-1, 1)], axis+1)
            self.root = self.build_tree(dataset)

        def predict(self, x):
            predictions = [self.predict_class(row, self.root) for row in x]
            return predictions

        def predict_class(self, row, node):
            if node.value != None:
                return node.value

            feature_val = row[node.feature_indx]
            if feature_val <= node.threshold:
                return self.predict_class(row, node.left)
            else:
                return self.predict_class(row, node.right)

# %%
class DecisionTree:
    def __init__(self, min_samples_split=2, max_depth=2):

        self.min_samples_split = min_sample_split
        self.max_depth = max_depth

    def build_tree(self, dataset, curr_depth=0):
        x, y = dataset[:, :-1], dataset[:, -1]
        n_samples, n_features = x.shape

        if n_samples >= self.min_samples_split and curr_dept <= self.max_depth:
            best_split = self.best_split(dataset, n_features)

            if best_split["info_gain"] > 0:
                left_node = self.build_tree(best_split["left_dataset"], curr_depth + 1)
                right_node = self.build_tree(best_split["right_dataset"], curr_depth + 1)

                return Node(best_split["feature_indx"], best_split["threshold"], best_split["info_gain"], left_node, right_node)

            left_value = Counter(y).most_common(1)[0][0]
            return Node(value=leaf_value)

    def best_split(self, dataset, n_features):
        best_split = {'feature_indx': None, 'threshold': None, 'info_gain': -1, 'left_dataset': None, 'right_dataset': None}

        for feature_indx in range(n_feature):
            feature_values = dataset[:, feature_indx]
            thresholds = np.unique(feature_values)

            for threshold in thresholds:
                left_dataset, right_dataset = self.split(dataset, feature_indx, threshold)

                if len(left_dataset) and len(right_dataset):
                    parent_y, left_y, right_y = dataset[:, -1], left_dataset[:, -1], right_dataset[:, -1]

                    info_gain = self.information_gain(parent_y, left_y, right_y)

                    if info_gain > best_split['info_gain']:
                        best_split['feature_indx'] = feature_indx
                        best_split['threshold'] = threshold
                        best_split['info_gain'] = info_gain
                        best_split['left_dataset'] = left_dataset
                        best_split['right_dataset'] = right_dataset

            return best_split

        def split(self, dataset, feature_indx, threshold):
            left_dataset = np.array([row for row in dataset if row[feature_indx] <= threshold])
            right_dataset =  np.array([row for row in dataset if row[feature_indx] > threshold])

            return left_dataset, right_dataset

        def information_gain(self, parent_y, left_y, right_y):
            left_weight = len(left_y) / len(parent_y)
            right_weight = len(right_y) / len(parent_y)

            information_gain = self.entropy(parent_y) - (left_weight * self.entropy(left_y) + right_weight * self.entropy(right_y))
            return information_gain

        def entropy(self, y):
            entropy = 0

            class_lables = np.unique(y)
            for class_label in class_lables:
                p = len(y[y==class_label]) / len(y)
                entropy += -p * np.log2(p)

            return entropy

        def fit(self, x, y):
            dataset = np.concatenate([x, y.reshape(-1, 1)], axis+1)
            self.root = self.build_tree(dataset)

        def predict(self, x):
            predictions = [self.predict_class(row, self.root) for row in x]
            return predictions

        def predict_class(self, row, node):
            if node.value != None:
                return node.value

            feature_val = row[node.feature_indx]
            if feature_val <= node.threshold:
                return self.predict_class(row, node.left)
            else:
                return self.predict_class(row, node.right)

# %%
dt = DecisionTreeClassifier(min_samples_split=2, max_depth=2)
dt.fit(x_train, y_train)
predictions = dt.predict(x_test)

accuracy = np.mean(predictions == y_test) * 100
print(f"Accuracy : {accuracy:.2f}%")
# Out:
# Accuracy : 96.67%

# %%
print(export_text(dt))
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: Iris-setosa
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- class: Iris-versicolor
# |   |--- feature_3 >  1.75
# |   |   |--- class: Iris-virginica
